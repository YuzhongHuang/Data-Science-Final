# %%
import pandas as pd
import numpy as np

# %%
basic_df = pd.read_csv('Processed_Transcript.csv')
diagnosis_df = pd.read_csv('combined_data.csv')

# %%
basic_df["Gender"] = basic_df["Gender"].apply(lambda x: 1 if x=='M' else 0)
basic_df["YearOfBirth"] = basic_df["YearOfBirth"].apply(lambda x:2012-x)
diagnosis_df = diagnosis_df.drop('Unnamed: 0', 1)

# %%
new_df = basic_df.merge(diagnosis_df, on='PatientGuid')

# %%
new_df = new_df.drop('PracticeGuid', 1)
new_df = new_df.drop('PatientGuid', 1)
new_df = new_df.drop('State', 1)
new_df = new_df.dropna()

# %%
def normalize(df, cols):
    for col in cols:
        df[col] = df[col].apply(lambda x: x/df[col].max()) 
        df[col] = df[col].apply(lambda x: 0.98 if x==1 else x) 
        df[col] = df[col].apply(lambda x: 0.02 if x==0 else x) 
    return df

new_df = normalize(new_df, new_df.columns.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3e5c96f335ab> in <module>()
#       7
#       8 new_df = normalize(new_df, new_df.columns.values)
# ----> 9 new_df.columns.value
#
# AttributeError: 'Index' object has no attribute 'value'

# %%
test_df = pd.read_csv('weights_table.csv')
test_df
# Out:
#     Unnamed: 0    Gender  YearOfBirth    Height    Weight  SystolicBP  \
# 0            0  0.538018     1.237973  0.819212  0.422607   -0.273039
# 1            1  0.369404    -0.185399 -1.271895 -0.412383    0.377148
# 2            2  0.201258    -0.858760 -0.152681 -0.035903    0.550660
# 3            3  0.609814    -0.074662 -0.890632 -0.047879   -0.662097
# 4            4 -0.147600    -1.010126 -0.252063 -0.194624    0.344959
# 5            5  0.996508    -1.433285  0.580332 -0.309084   -0.606161
# 6            6 -0.637737     1.436671 -0.211974  0.416621   -0.353592
# 7            7  1.405166     1.277867  0.598994  0.166174    0.251479
# 8            8 -1.413754     1.131027 -0.760298 -0.094572    0.191197
# 9            9 -0.480668    -1.235384 -0.374905 -0.244130    0.319144
# 10          10  1.138912    -1.256202 -1.432917  0.109695   -0.317734
# 11          11 -1.415277    -0.823580 -0.559229 -0.121876    0.251007
# 12          12 -0.953536    -1.991883  0.494900  0.723847   -0.630129
# 13          13  0.333917     1.502825  0.882488 -0.421697    0.521765
# 14          14 -0.293635     0.163768 -0.842491  0.102946   -0.096880
# 15          15  0.726077     0.405856 -0.275094  0.213731    0.362054
# 16          16 -1.127987    -0.241417 -0.834618 -0.224545   -0.348684
# 17          17 -1.806573     0.008053  0.740326 -0.143763   -0.532927
# 18          18  0.046798     0.262621 -0.795541  0.480046   -0.476619
# 19          19 -0.114248    -0.210050 -0.228893  0.414807    0.326122
# 20          20 -0.602544     0.195447 -1.114702 -0.040949    0.028655
# 21          21 -0.880831     0.940996 -0.678502 -0.255782    0.338074
#
#     DiastolicBP  RespiratoryRate  Temperature     blood    ...     \
# 0      0.418556         0.208075    -0.053843  0.035146    ...
# 1      0.412165        -0.410119    -0.657715 -0.023252    ...
# 2     -0.117008         0.283825     0.117500 -0.245957    ...
# 3     -0.506609        -0.529580     0.163230  0.553779    ...
# 4      0.111721        -0.378572    -0.266266  0.235789    ...
# 5     -0.064917         0.411613    -0.511398  0.318657    ...
# 6      0.391711         0.561401    -0.345501  0.258459    ...
# 7     -0.295666        -0.221744     0.063860  0.104177    ...
# 8      0.172430        -0.436912     0.021549  0.704325    ...
# 9      0.084832         0.499475     0.737050  0.729083    ...
# 10     0.108140        -0.362751     0.221507  0.413798    ...
# 11     0.193206        -0.458427    -0.266662  0.323673    ...
